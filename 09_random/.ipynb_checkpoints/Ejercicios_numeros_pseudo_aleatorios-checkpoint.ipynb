# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import math 
import itertools

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 01</font></b>
#
# El método **Montecarlo** es un método no determinista o estadístico numérico, usado para aproximar expresiones matemáticas complejas y costosas de evaluar con exactitud. El método se llamó así en referencia al Casino de Montecarlo (Mónaco) por ser “la capital del juego de azar”, al ser la ruleta un generador simple de números aleatorios. El nombre y el desarrollo sistemático de los métodos de Montecarlo datan aproximadamente de 1944 testee combinaciones posibles.
#
# Vamos a calcular el valor de $\pi$, para ello, si $X$ e $Y$ son dos variables aleatorias continuas uniformes en el intervalo (-1,1) y son independientes.
# $\pi$ Vendrá dada por la probabilidad de que $X^2 + Y^2  \leq 1$, es decir:
# $$\pi = \frac{4*\text{nº puntos que caén dentro}}{\text{nº total de intentos}}$$
# Obten tambien una gráfica como la que se muestra a continuación.

# %%
N=10000 #número de intentos
#ayuda plt.figure(figsize=(8,8))
"""Esribe tu código aquí"""
x = np.random.uniform(-1, 1, size=N)
y = np.random.uniform(-1, 1, size=N)

formula = x**2 + y**2 <= 1

plt.figure(figsize=(8,8))
plt.scatter(x[formula], y[formula], color='magenta',s=2, alpha=0.5)
plt.scatter(x[~formula], y[~formula], color='b', s=2, alpha=0.5)

plt.show()

# %% [markdown]
# <img src="f6.png">

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 02</font></b>
#
# Crea un histograma en que se vea la distribución que saldría al sumar dos dados, tiene que verse una gráfica como la que se muestra a continuación

# %%
sumas=[]
for _ in range(10000):
    sumas.append(random.randint(1, 6) + random.randint(1, 6))
plt.hist(sumas, bins=range(2, 14), density=True)
plt.grid()
plt.xticks(range(2, 14))
plt.show()

# %% [markdown]
# <img src="f7.png">

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 03</font></b>
#
# Al implementar MD5, obtendremos como resultado, una cadena alfanumérica de 32 caracteres hexadecimales. Ocupando siempre 16 Bytes de memoria.
#
# El siguiente pin = '4aca32b706287f13903f08b7aab38f79', ha sido codificado con md5 "hashlib.md5(b'****')", para ello han utilizado dos carácteres en mayúsculas ('ABCDEF')  y dos números (0-9) , haz una función que obtenga el pin descodificado utilizando random.
#
# ¿Cuántos intentos ha relizado hasta que la ha descubierto?
# Realiza el ejercicio varias veces y haz un histograma.

# %%
import hashlib
import numpy as np
import string
import random
contra = '4aca32b706287f13903f08b7aab38f79'
def descifrar(n_ejecuciones):
    letras = string.ascii_uppercase[:6]  # Letras de la 'A' a la 'F'
    intentos = []

    for _ in range(n_ejecuciones):
        contador = 0
        encontrado = False

        while not encontrado:
            aleatorio = [random.choice(letras), random.choice(letras),str(random.randint(0, 9)), str(random.randint(0, 9))]
            np.random.shuffle(aleatorio)
            intentoString = ''.join(aleatorio)

            intento = hashlib.md5(intentoString.encode()).hexdigest()

            if intento == contra:
                encontrado = True
            contador += 1

        intentos.append(contador)

    return intentos

intentos = descifrar(10)
print(intentos)
plt.hist(intentos, bins=10, color='blue', alpha=0.7)
plt.show()
# Out:
# [4575, 13431, 62478, 3033, 6897, 9207, 3438, 51797, 15855, 28150]

# %% [markdown]
# # <hr>
# <b><font color='red'>Ejercicio 04</font></b>
#
# <img src="ruleta.png">
#
# La ruleta europea tiene 37 números, de los cuales 18 son rojos, 18 negros y el 0, que es verde, entre las diversas apuestas existe la de de apostar todo a rojos o negros, en este caso si se gana, se ganaría lo mismo que se ha apostado.
#
# Haz la siguiente simulación, empezando con una cantidad de 1000 euros, apostando de forma constante 50 Euros, haz que la maquina apueste siempre a los pares o a los impares, en ambos casos si sale 0 se perderia lo apostado.

# %%
saldo = 1000
apuesta = 50
nSimulaciones = 1000
contador=1
while(saldo>0):
    apostado=random.choice([1,2])
    resultado_ruleta = np.random.randint(0, 37)

    if resultado_ruleta % 2 == 0 and resultado_ruleta != 0 and apostado==2:
        saldo += apuesta
    elif resultado_ruleta % 2 != 0 and resultado_ruleta != 0 and apostado==1:
        saldo +=  apuesta
    else:
        saldo -= apuesta

    print("Ronda",contador,":",saldo)
    contador += 1
# Out:
# Ronda 1 : 950
# Ronda 2 : 1000
# Ronda 3 : 950
# Ronda 4 : 900
# Ronda 5 : 850
# Ronda 6 : 800
# Ronda 7 : 850
# Ronda 8 : 900
# Ronda 9 : 950
# Ronda 10 : 900
# Ronda 11 : 850
# Ronda 12 : 800
# Ronda 13 : 750
# Ronda 14 : 800
# Ronda 15 : 750
# Ronda 16 : 800
# Ronda 17 : 750
# Ronda 18 : 800
# Ronda 19 : 750
# Ronda 20 : 700
# Ronda 21 : 750
# Ronda 22 : 800
# Ronda 23 : 850
# Ronda 24 : 900
# Ronda 25 : 950
# Ronda 26 : 1000
# Ronda 27 : 1050
# Ronda 28 : 1000
# Ronda 29 : 1050
# Ronda 30 : 1000
# Ronda 31 : 950
# Ronda 32 : 1000
# Ronda 33 : 950
# Ronda 34 : 900
# Ronda 35 : 850
# Ronda 36 : 900
# Ronda 37 : 850
# Ronda 38 : 900
# Ronda 39 : 950
# Ronda 40 : 1000
# Ronda 41 : 1050
# Ronda 42 : 1000
# Ronda 43 : 950
# Ronda 44 : 900
# Ronda 45 : 950
# Ronda 46 : 1000
# Ronda 47 : 950
# Ronda 48 : 1000
# Ronda 49 : 950
# Ronda 50 : 1000
# Ronda 51 : 950
# Ronda 52 : 1000
# Ronda 53 : 950
# Ronda 54 : 900
# Ronda 55 : 950
# Ronda 56 : 1000
# Ronda 57 : 1050
# Ronda 58 : 1000
# Ronda 59 : 1050
# Ronda 60 : 1000
# Ronda 61 : 950
# Ronda 62 : 1000
# Ronda 63 : 950
# Ronda 64 : 900
# Ronda 65 : 950
# Ronda 66 : 1000
# Ronda 67 : 1050
# Ronda 68 : 1000
# Ronda 69 : 950
# Ronda 70 : 900
# Ronda 71 : 950
# Ronda 72 : 1000
# Ronda 73 : 1050
# Ronda 74 : 1000
# Ronda 75 : 950
# Ronda 76 : 1000
# Ronda 77 : 950
# Ronda 78 : 900
# Ronda 79 : 850
# Ronda 80 : 900
# Ronda 81 : 950
# Ronda 1042 : 600
# Ronda 1043 : 550
# Ronda 1044 : 500
# Ronda 1045 : 450
# Ronda 1046 : 500
# Ronda 1047 : 550
# Ronda 1048 : 500
# Ronda 1049 : 450
# Ronda 1050 : 500
# Ronda 1051 : 550
# Ronda 1052 : 500
# Ronda 1053 : 450
# Ronda 1054 : 500
# Ronda 1055 : 450
# Ronda 1056 : 400
# Ronda 1057 : 350
# Ronda 1058 : 300
# Ronda 1059 : 350
# Ronda 1060 : 300
# Ronda 1061 : 250
# Ronda 1062 : 200
# Ronda 1063 : 250
# Ronda 1064 : 200
# Ronda 1065 : 150
# Ronda 1066 : 200
# Ronda 1067 : 250
# Ronda 1068 : 300
# Ronda 1069 : 350
# Ronda 1070 : 400
# Ronda 1071 : 450
# Ronda 1072 : 500
# Ronda 1073 : 550
# Ronda 1074 : 500
# Ronda 1075 : 550
# Ronda 1076 : 600
# Ronda 1077 : 550
# Ronda 1078 : 500
# Ronda 1079 : 450
# Ronda 1080 : 400
# Ronda 1081 : 450
# Ronda 1082 : 500
# Ronda 1083 : 450
# Ronda 1084 : 400
# Ronda 1085 : 350
# Ronda 1086 : 300
# Ronda 1087 : 350
# Ronda 1088 : 400
# Ronda 1089 : 350
# Ronda 1090 : 400
# Ronda 1091 : 350
# Ronda 1092 : 300
# Ronda 1093 : 250
# Ronda 1094 : 200
# Ronda 1095 : 250
# Ronda 1096 : 300
# Ronda 1097 : 350
# Ronda 1098 : 300
# Ronda 1099 : 350
# Ronda 1100 : 300
# Ronda 1101 : 250
# Ronda 1102 : 200
# Ronda 1103 : 250
# Ronda 1104 : 200
# Ronda 1105 : 150
# Ronda 1106 : 100
# Ronda 1107 : 50
# Ronda 1108 : 100
# Ronda 1109 : 50
# Ronda 1110 : 0

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 05</font></b>
#
# Utiliza 10 jugadores y haz el promedio de veces en lo que tardarían en arruinarse

# %%
promedio=[]
for i in range(0,10):
    saldo = 1000
    apuesta = 50
    nSimulaciones = 1000
    contador=1
    while(saldo>0):
        apostado=random.choice([1,2])
        resultado_ruleta = np.random.randint(0, 37)

        if resultado_ruleta % 2 == 0 and resultado_ruleta != 0 and apostado==2:
            saldo += apuesta
        elif resultado_ruleta % 2 != 0 and resultado_ruleta != 0 and apostado==1:
            saldo +=  apuesta
        else:
            saldo -= apuesta
        contador += 1
    promedio.append(contador)
print(sum(promedio) / len(promedio))
# Out:
# 1179.4

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 06</font></b>
#
# Obten la siguiente evolución respecto el número de jugadores:
#
#     print("%6d" % njugadores,"%.1f" % a.mean(),"%.0f"%a.std())
#         10 636.8 624
#         20 603.0 799
#         50 799.2 875
#        100 558.1 500
#        200 921.6 1236
#        500 744.2 936
#       1000 726.1 1021
#       5000 734.3 967
#      10000 734.5 1021

# %%
def simulacion_ruleta(njugadores):
    resultados = []

    for _ in range(njugadores):
        saldo = 1000
        apuesta = 50
        contador = 1

        while saldo > 0:
            apostado = random.choice([1, 2])
            resultado_ruleta = np.random.randint(0, 37)

            if resultado_ruleta % 2 == 0 and resultado_ruleta != 0 and apostado == 2:
                saldo += apuesta
            elif resultado_ruleta % 2 != 0 and resultado_ruleta != 0 and apostado == 1:
                saldo += apuesta
            else:
                saldo -= apuesta

            contador += 1

        resultados.append(contador)

    return np.array(resultados)

njugadores_lista = [10, 20, 50, 100, 200, 500, 1000, 5000, 10000]

resultados_simulacion = []
for njugadores in njugadores_lista:
    a = simulacion_ruleta(njugadores)
    media = a.mean()
    desviacion_estandar = a.std()
    resultados_simulacion.append((njugadores, media, desviacion_estandar))

print(resultados_simulacion)
# Out:
# [(10, 518.6, 705.8094927103206),
#  (20, 459.4, 392.13497676182874),
#  (50, 937.2, 1679.386852395838),
#  (100, 687.5, 714.571333038207),
#  (200, 589.34, 873.2205015916655),
#  (500, 674.144, 856.2422106296792),
#  (1000, 724.074, 919.3397557617096),
#  (5000, 740.2268, 976.5627532123883),
#  (10000, 764.9886, 1049.5368892373626)]

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 07</font></b>
#
# Empezamos con el problema del viajante, (Travelling Salesman Problem) responde a la siguiente pregunta: dada una lista de ciudades y las distancias entre cada par de ellas, ¿cuál es la ruta más corta posible que visita cada ciudad exactamente una vez y al finalizar regresa a la ciudad origen? Este es un problema NP-Hard dentro en la optimización combinatoria, muy importante en investigación operativa y en ciencias de la computación.
# En el siguiente problema partiendo de Madrid tenemos que pasar por las siguientes ciudades

# %%
from ipyleaflet import Map, Polyline
from ipyleaflet import Map, basemaps, basemap_to_tiles, Circle

ciudad = [[40.4950873744,-3.71704619215],
[41.6207742504,-2.58874304739],
[38.4786378049,-0.568699068376],
[42.0439686698,1.04798206104],
[36.5538729195,-5.7604183752],
[40.8049892162,-6.06541224773],
[42.435764706,-8.46106294738],
[38.0165122783,-3.44169215171],
[41.6203648019,-1.06449678144],
[42.1280117119,2.6735559327],
[43.292357861,-5.99350932547]]
 
line = Polyline(
    locations=ciudad,
    color="blue" ,
    weight = 2,
    fill=False
)
c=ciudad[0]
m = Map(center = ciudad[0], zoom =5.4)
for i in ciudad:
    circle = Circle()
    circle.location = i
    circle.radius = 5000
    circle.color = "blue"
    circle.fill_color = "blue"
    m.add_layer(circle)
m.add_layer(line)

distancias=[]
for i in ciudad:
    if(i!=c):
        resultado=((c[0]-i[0])/(c[1]-i[1]))
        if resultado<0:
            resultado=resultado*-1
        distancias.append(resultado)
print(distancias)
# Out:
# [0.9976812359584794, 0.6404787941816371, 0.3250518597372609, 1.9287795378604111, 0.13196487875628868, 0.40907893705487386, 9.001411753898282, 0.4242248694620178, 0.25551963736724237, 1.2287791731203888]

# %% [markdown]
# Crea una función que obtenga el recorrido realizado, testeala con el orden actual de ciudades
#
#     sol : d = 435.6697061255633

# %%
"""Esribe tu código aquí"""
def calculaRecorrido(distancias):
    total=0
    for i in distancias:
        total=total+i*2
    return total

print(calculaRecorrido(distancias))
# Out:
# 30.685941354793762
